# %% [markdown]
# # Seaborn

# %% [markdown]
# - Construída por Michael Waskom
# - Construida sobre Matplotlib
# - Integrada para estructuras de Pandas

# %% [markdown]
# ## Por qué Seaborn?
#
# - Velocidad
# - Poco código
# - Customizable

# %% [markdown]
# ## Estructura básica
#
# ```{python}
# sns."Tipo de gráfica"(
#     data="Dataset,
#     x="Data en el eje x",
#     y="Data en el eje y",
#     hue="Variable de agrupamiento"
# )
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
